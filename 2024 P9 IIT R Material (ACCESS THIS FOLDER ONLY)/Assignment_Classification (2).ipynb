# %% [markdown]
# Import the necessary libraries

# %% [markdown]
# Import the fruit_data.csv dataset

# %%
df = pd.read_csv('fruit_data.csv', sep = '\t')

# %% [markdown]
# Check the head, shape and statistical summarry for the dataset

# %% [markdown]
# Check null values

# %% [markdown]
# Identify the unique labels present in the dataset

# %% [markdown]
# Check value counts for different types of fruits

# %% [markdown]
# Create boxplots for the input variables

# %% [markdown]
# Create variables X and y for developing a classfication model

# %% [markdown]
# Perform train-test split

# %% [markdown]
# Standardize the values

# %% [markdown]
# Build a MLPClassifier model and check its performance for the given dataset
